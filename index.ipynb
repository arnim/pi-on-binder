# %% [markdown]
# # Quick tour: pi-on-binder
#
# Welcome! This Binder ships with **[pi-coding-agent](https://www.npmjs.com/package/@earendil-works/pi-coding-agent)**, **Python 3.11**, and **R 4.4** - everything you need for AI-assisted coding, data exploration and modelling.

# %% [markdown]
# ---
#
# ## 🤖 pi-coding-agent
#
# An instance of pi should have automatically started in a panel.
#
# ### From Jupyter launcher
#
# To start a new instance of pi, click the **Pi Agent** icon (with the pi logo) in the Jupyter launcher.
# It opens a terminal and runs pi with `pi --model openrouter/deepseek/deepseek-v4-pro --approve` automatically.
#
# Alternatively, open a terminal and type `pi`.

# %% [markdown]
# ---
#
# ## 🔬 Python quick start
#
# Create a new notebook, select the **Python 3** kernel, and go:

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

df = pd.DataFrame({'x': np.linspace(0, 10, 50)})
df['y'] = np.sin(df['x']) + np.random.randn(50) * 0.1

sns.lineplot(data=df, x='x', y='y')
plt.title('Hello from Python!')
plt.show()

# %% [markdown]
# ---
#
# ## 📊 R quick start
#
# Create a new notebook, select the **R** kernel:

# %%
library(ggplot2)

df <- data.frame(x = seq(0, 10, length.out = 50))
df$y <- sin(df$x) + rnorm(50, sd = 0.1)

ggplot(df, aes(x, y)) +
  geom_line(colour = 'steelblue', size = 1) +
  ggtitle('Hello from R!')

# %% [markdown]
# ---
#
# ## 🌐 Useful links
#
# - [pi-coding-agent on npm](https://www.npmjs.com/package/@earendil-works/pi-coding-agent)
# - [pi.dev](https://pi.dev)
# - [MyBinder docs](https://mybinder.readthedocs.io)
